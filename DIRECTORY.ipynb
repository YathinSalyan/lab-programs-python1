# %%
import os
import shutil

def get_current_directory():
    print(f"Current Working Directory: {os.getcwd()}")

def list_files_and_directories():
    files_and_directories = os.listdir()
    print("\nFiles and Directories in the Current Directory:")
    for item in files_and_directories:
        print(item)

def create_new_directory():
    new_directory_name = input("Enter the name of the new directory: ")
    os.mkdir(new_directory_name)
    print(f"Directory '{new_directory_name}' created successfully.")

def verify_directory_existence():
    directory_name = input("Enter the name of the directory to verify: ")
    if os.path.exists(directory_name) and os.path.isdir(directory_name):
        print(f"The directory '{directory_name}' exists.")
    else:
        print(f"The directory '{directory_name}' does not exist.")

def copy_file_to_directory():
    source_file = input("Enter the name of the file to copy: ")
    destination_directory = input("Enter the name of the destination directory: ")
    shutil.copy(source_file, destination_directory)
    print(f"File '{source_file}' copied to '{destination_directory}'.")

# Menu
while True:
    print("\nMenu:")
    print("1. Get Current Working Directory")
    print("2. List Files and Directories")
    print("3. Create a New Directory")
    print("4. Verify Directory Existence")
    print("5. Copy a File to Directory")
    print("6. Quit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        get_current_directory()
    elif choice == 2:
        list_files_and_directories()
    elif choice == 3:
        create_new_directory()
    elif choice == 4:
        verify_directory_existence()
    elif choice == 5:
        copy_file_to_directory()
    elif choice == 6:
        break
    else:
        print("Invalid choice. Please enter a valid option.")
# Out:
# Menu:
# 1. Get Current Working Directory
# 2. List Files and Directories
# 3. Create a New Directory
# 4. Verify Directory Existence
# 5. Copy a File to Directory
# 6. Quit
# Enter your choice: 1
# Current Working Directory: C:\Users\User
#
# Menu:
# 1. Get Current Working Directory
# 2. List Files and Directories
# 3. Create a New Directory
# 4. Verify Directory Existence
# 5. Copy a File to Directory
# 6. Quit
# Enter your choice: 2
#
# Files and Directories in the Current Directory:
# .android
# .conda
# .condarc
# .continuum
# .emulator_console_auth_token
# .gradle
# .idea
# .ipynb_checkpoints
# .ipython
# .jupyter
# .keras
# .keras-ocr
# .m2
# .matplotlib
# .templateengine
# 001_Python_Dictionary_clear().ipynb
# 002_Python_Dictionary_copy().ipynb
# 3D Objects
# AllProductReviews.csv
# anaconda3
# AndroidStudioProjects
# AppData
# Application Data
# blobs.csv
# calculator using python.ipynb
# chota.jpg
# constructor in python.ipynb
# Contacts
# Cookies
# decision.csv
# Desktop
# Documents
# Downloads
# dpython
# ds.csv
# exam
# example codes nov 07.ipynb
# example nov 09 2023 .ipynb
# Favorites
# feature extraction 2.ipynb
# feature extraction.ipynb
# fibanocci.ipynb
# fruit.csv
# Hifaza
# homeprices.csv
# homo_eng_3_train.csv
# img400.png
# insurance.csv
# IntelGraphicsProfiles
# iris2.csv
# java_error_in_studio64.hprof
# lab DEC 05 2023.ipynb
# lab DEC 07 23.ipynb
# linear.csv
# Links
# LOAD,DELETE,RENAME THE FILE.ipynb
# Local Settings
# logistic.csv
# loops nov16.ipynb
# Mall_Customers.csv
# masha.jpg
# METHOD OVERLOADING.ipynb
# ML exam
# movie_review.csv
# multiple.csv
# Music
# My Documents
# NetHood
# nov 21 2023.ipynb
# nov 21 doraemon.ipynb
# nov 21 turtle graphics.ipynb
# nov 23 2023.ipynb
# NTUSER.DAT
# ntuser.dat.LOG1
# ntuser.dat.LOG2
# NTUSER.DAT{cf4480e0-850a-11ec-ab1c-a4ae111a3e29}.TM.blf
# NTUSER.DAT{cf4480e0-850a-11ec-ab1c-a4ae111a3e29}.TMContainer00000000000000000001.regtrans-ms
# NTUSER.DAT{cf4480e0-850a-11ec-ab1c-a4ae111a3e29}.TMContainer00000000000000000002.regtrans-ms
# ntuser.ini
# OneDrive
# operator overloading and etc.ipynb
# Pictures
# PrintHood
# PYTHON INTERNAL LAB PROGRAM .ipynb
# Recent
# samp.csv
# sample_text - Sheet1 (1).csv
# sample_text - Sheet1.csv
# Saved Games
# ScStore
# Searches
# SendTo
# sentimental analysis.ipynb
# sentimental analysis2.ipynb
# sentiment_tweets3.csv
# Social_Network_Ads.csv
# speech_barack_obama.txt
# speech_michelle_obama.txt
# Start Menu
# sudoku DEC 07.ipynb
# TELUGU_DEVELOPMENT DATA.csv
# TELUGU_TRAINING_DATA.csv
# Templates
# test.csv
# test.ipynb
# Trial1.wav
# twcs.csv
# Twitter_Data.csv
# Untitled.ipynb
# Untitled1.ipynb
# Untitled10.ipynb
# Untitled11.ipynb
# Untitled12.ipynb
# Untitled13.ipynb
# Untitled14.ipynb
# Untitled15.ipynb
# Untitled16.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# Untitled6.ipynb
# Untitled7.ipynb
# Untitled8.ipynb
# Untitled9.ipynb
# Videos
# your_output_file.csv
#
# Menu:
# 1. Get Current Working Directory
# 2. List Files and Directories
# 3. Create a New Directory
# 4. Verify Directory Existence
# 5. Copy a File to Directory
# 6. Quit
# Enter your choice: 3
# Enter the name of the new directory: untitled1
# Directory 'untitled1' created successfully.
#
# Menu:
# 1. Get Current Working Directory
# 2. List Files and Directories
# 3. Create a New Directory
# 4. Verify Directory Existence
# 5. Copy a File to Directory
# 6. Quit
# Enter your choice: 4
# Enter the name of the directory to verify: untitled1
# The directory 'untitled1' exists.
#
# Menu:
# 1. Get Current Working Directory
# 2. List Files and Directories
# 3. Create a New Directory
# 4. Verify Directory Existence
# 5. Copy a File to Directory
# 6. Quit
# Enter your choice: 6
